# %% [markdown]
# # Text Representation & Sentiment Analsis

# %% [markdown]
# ## Import Libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Import Data

# %%
data = pd.read_csv("Data/CleanData.csv")
data = data.dropna().drop_duplicates().reset_index(drop=True)
